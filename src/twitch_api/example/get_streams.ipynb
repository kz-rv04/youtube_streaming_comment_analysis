# %%
import os
import sys
sys.path.append('../')

import pandas as pd

import twitch_api as ta

# %%
res = ta.get_streams(limit=100, offset=0)

# %%
df = pd.io.json.json_normalize(res['streams'])

# %%
df[df['channel.broadcaster_language']=='ja']
# Out:
#             _id  average_fps broadcast_platform  channel._id  \
# 7   39846717102           59               live    104833324
# 15  39846756654           60               live     50988750
# 64  39840216958           60               live     10985633
# 75  39847250222           29               live    132922684
#
#    channel.broadcaster_language channel.broadcaster_software  \
# 7                            ja
# 15                           ja
# 64                           ja
# 75                           ja
#
#    channel.broadcaster_type           channel.created_at  \
# 7                            2015-10-21T04:32:05.637207Z
# 15                           2013-11-02T14:39:22.483111Z
# 64                           2010-03-09T06:47:08.075757Z
# 75                           2016-08-23T03:06:03.232451Z
#
#                          channel.description channel.display_name  ...  delay  \
# 7               RiotGamesJapanの公式チャンネルへようこそ！          RiotGamesJP  ...      0
# ...
